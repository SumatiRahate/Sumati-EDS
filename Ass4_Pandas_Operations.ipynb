# %% [markdown]
# <a href="https://colab.research.google.com/github/SumatiRahate/Sumati-EDS/blob/main/Ass4_Pandas_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('/content/pra4_350.csv')
print(data)
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0         198.0     Donald   OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1         199.0    Douglas      Grant    DGRANT  650.507.9844  13-Jan-08
# 2         200.0   Jennifer     Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3         201.0    Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4         202.0        Pat        Fay      PFAY  603.123.6666  17-Aug-05
# ..          ...        ...        ...       ...           ...        ...
# 63          NaN        NaN        NaN       NaN           NaN        NaN
# 64          NaN        NaN        NaN       NaN           NaN        NaN
# 65          NaN        NaN        NaN       NaN           NaN        NaN
# 66          NaN        NaN        NaN       NaN           NaN        NaN
# 67          NaN        NaN        NaN       NaN           NaN        NaN
#
#       JOB_ID   SALARY MANAGER_ID  DEPARTMENT_ID  ...  Unnamed: 16  \
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/pra4_350.csv')
print(df)
#drop rows of nan(not a number)
nan_df = data[data.isnull().any(axis=1)]
display(nan_df.head())

data=data.dropna(how='all')
data.head()
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0         198.0     Donald   OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1         199.0    Douglas      Grant    DGRANT  650.507.9844  13-Jan-08
# 2         200.0   Jennifer     Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3         201.0    Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4         202.0        Pat        Fay      PFAY  603.123.6666  17-Aug-05
# ..          ...        ...        ...       ...           ...        ...
# 63          NaN        NaN        NaN       NaN           NaN        NaN
# 64          NaN        NaN        NaN       NaN           NaN        NaN
# 65          NaN        NaN        NaN       NaN           NaN        NaN
# 66          NaN        NaN        NaN       NaN           NaN        NaN
# 67          NaN        NaN        NaN       NaN           NaN        NaN
#
#       JOB_ID   SALARY MANAGER_ID  DEPARTMENT_ID  ...  Unnamed: 16  \
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/pra4_350.csv')

df.dropna(axis=1, how='all', inplace=True)
df.to_csv('clean_data.csv', index=False)
df
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0         198.0     Donald   OConnell  DOCONNEL  650.507.9833  21-Jun-07
# 1         199.0    Douglas      Grant    DGRANT  650.507.9844  13-Jan-08
# 2         200.0   Jennifer     Whalen   JWHALEN  515.123.4444  17-Sep-03
# 3         201.0    Michael  Hartstein  MHARTSTE  515.123.5555  17-Feb-04
# 4         202.0        Pat        Fay      PFAY  603.123.6666  17-Aug-05
# ..          ...        ...        ...       ...           ...        ...
# 63          NaN        NaN        NaN       NaN           NaN        NaN
# 64          NaN        NaN        NaN       NaN           NaN        NaN
# 65          NaN        NaN        NaN       NaN           NaN        NaN
# 66          NaN        NaN        NaN       NaN           NaN        NaN
# 67          NaN        NaN        NaN       NaN           NaN        NaN
#
#       JOB_ID   SALARY MANAGER_ID  DEPARTMENT_ID Unnamed: 25
# ...

# %%
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE      JOB_ID    SALARY MANAGER_ID  DEPARTMENT_ID Unnamed: 25
# 0         198.0       Donald     OConnell  DOCONNEL  650.507.9833  21-Jun-07    SH_CLERK    2600.0        124           50.0         NaN
# 1         199.0      Douglas        Grant    DGRANT  650.507.9844  13-Jan-08    SH_CLERK    2600.0        124           50.0         NaN
# 2         200.0     Jennifer       Whalen   JWHALEN  515.123.4444  17-Sep-03     AD_ASST    4400.0        101           10.0         NaN
# 3         201.0      Michael    Hartstein  MHARTSTE  515.123.5555  17-Feb-04      MK_MAN   13000.0        100           20.0         NaN
# 4         202.0          Pat          Fay      PFAY  603.123.6666  17-Aug-05      MK_REP    1600.0        201           20.0         NaN
# 5         203.0        Susan       Mavris   SMAVRIS  515.123.7777  07-Jun-02      HR_REP    6500.0        101           40.0         NaN
# ...

# %%
#read new cleanup file
import numpy as np
import pandas as pd
data = pd.read_csv('/content/clean_data.csv')
print(data)


#make columns correct type
data['SALARY'] = pd.to_numeric(data['SALARY'])
print(data)
#year using datetime function
import datetime as dt
data['YEAR'] = pd.to_datetime(data['HIRE_DATE']).dt.year
data.head()
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0         110.0         John         Chen     JCHEN  515.124.4269  28-Sep-05
# 1         111.0       Ismael      Sciarra  ISCIARRA  515.124.4369  30-Sep-05
# 2         112.0  Jose Manuel        Urman   JMURMAN  515.124.4469  07-Mar-06
# 3         113.0         Luis         Popp     LPOPP  515.124.4567  07-Dec-07
# 4         114.0          Den     Raphaely  DRAPHEAL  515.127.4561  07-Dec-02
# 5         115.0    Alexander         Khoo     AKHOO  515.127.4562  18-May-03
# 6         116.0       Shelli        Baida    SBAIDA  515.127.4563  24-Dec-05
# 7         117.0        Sigal       Tobias   STOBIAS  515.127.4564  24-Jul-05
# 8         118.0          Guy       Himuro   GHIMURO  515.127.4565  15-Nov-06
# 9         119.0        Karen   Colmenares  KCOLMENA  515.127.4566  10-Aug-07
# 10        120.0      Matthew        Weiss    MWEISS  650.123.1234  18-Jul-04
# ...

# %%
import csv

# Open the CSV file
with open('/content/pra4_350.csv', 'r') as file:

    # Create a CSV reader object
    reader = csv.reader(file)
    next(reader)

    # Extract the desired column values into a list
    salary = [row[7] for row in reader]  # Replace 2 with the index of the desired column (zero-based index)

print(salary)
# Out:
# ['2600', '2600', '4400', '13000', '1600', '6500', '10000', '12800', '8300', '24000', '17000', '17000', '9000', '6000', '48000', '4800', '43000', '120000', '9000', '66000', '7700', '78000', '69000', '10000', '3300', '3000', '3200', '2800', '3500', '8009', '8000', '78000', '6500', '5800', '3200', '2700', '2400', '2200', '3300', '2800', '3500', '2000', '3500', '3000', '2500', '2100', '3600', '4500', '2900', '2300', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']

# %%
salary1 = [int(item) for item in salary]

print(salary1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-4c7e68657f8f> in <cell line: 1>()
# ----> 1 salary1 = [int(item) for item in salary]
#       2
#       3 print(salary1)
#       4
#       5
#
# <ipython-input-26-4c7e68657f8f> in <listcomp>(.0)
# ----> 1 salary1 = [int(item) for item in salary]
#       2
#       3 print(salary1)
#       4
#       5
#
# ValueError: invalid literal for int() with base 10: ''
